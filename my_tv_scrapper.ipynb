# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "tv"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
# urlclient = urlopen(flipkart_url, context=None)

# %%
response = requests.get(flipkart_url)
content = response.content

# %%
content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
flipkar_html = bs(content, 'html.parser')

# %%
flipkar_html

# %%
bigbox = flipkar_html.find_all("div", {"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:3]

# %%
productlink = "https://www.flipkart.com" + bigbox[0].div.div.div.a['href']

# %%
for i in bigbox:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/iffalcon-tcl-u62-139-cm-55-inch-ultra-hd-4k-led-smart-google-tv-dolby-audio-hdr10/p/itmf58a1d1c2ef93?pid=TVSGGJTQPBRFGGZK&lid=LSTTVSGGJTQPBRFGGZKXB2HSI&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=e485fb7e-11db-45fe-9ab7-4e57b3201a26.TVSGGJTQPBRFGGZK.SEARCH&ppt=None&ppn=None&ssid=egq8ftbfqo0000001704557239328&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/realme-108-cm-43-inch-full-hd-led-smart-android-tv-2022-11/p/itmb9eae427e9053?pid=TVSGDC5CFDS55XDC&lid=LSTTVSGDC5CFDS55XDCBDARJO&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=e485fb7e-11db-45fe-9ab7-4e57b3201a26.TVSGDC5CFDS55XDC.SEARCH&ppt=None&ppn=None&ssid=egq8ftbfqo0000001704557239328&qH=c9a1fdac6e082dd8
# ...

# %%
productreq = requests.get(productlink)

# %%
a = productreq.content

# %%
product_html = bs(a, 'html.parser')

# %%
comment_box = product_html.find_all("div", {"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Flipkart Customer'

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Flipkart Customer
# Arijit Sanyal
# VALLARASU MURUGAN
# ALANKAR PATIL
# Flipkart Customer
# Flipkart Customer
# NANDA GOPAL
# Flipkart Customer
# Flipkart Customer
# Potharajula  Rajkumar
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 4
# 5
# 4
# 5
# 5
# 5
# 5
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Very Good'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Very Good
# Excellent
# Very Good
# Must buy!
# Terrific
# Awesome
# Mind-blowing purchase
# Does the job
# Pretty good
# Classy product
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.find_all("div",{"class":""})[0].text
# Out:
# 'Pros1. Automatic Connectivity with wifi hotspot is better than mi Android box.2. Remote with Superb handy design and quality buttons3. Multiple picture settings allow us to suit our needs.4. Bluetooth headphones can be connected5. Almost all apps working fine and smoothCons:-1. The picture quality is good and not at all whitish screen like low budget tv; But the best picture quality is only visible while sitting directly on front of tv, if we move a bit from the exact front, it reduce...READ MORE'

# %%
for i in comment_box:
    print(i.div.div.find_all("div",{"class":""})[0].text)
# Out:
# Pros1. Automatic Connectivity with wifi hotspot is better than mi Android box.2. Remote with Superb handy design and quality buttons3. Multiple picture settings allow us to suit our needs.4. Bluetooth headphones can be connected5. Almost all apps working fine and smoothCons:-1. The picture quality is good and not at all whitish screen like low budget tv; But the best picture quality is only visible while sitting directly on front of tv, if we move a bit from the exact front, it reduce...READ MORE
# I have been an old user of Iffalcon TV since 2019 and this is my second purchase. The TV works great, great picture quality and great sound. Easy to connect...Google TV is smooth and useful. And in this price point it is the best you can buy.READ MORE
# Picture quality is  ok....Overall goodREAD MORE
# ...
